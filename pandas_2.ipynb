# %% [markdown]
# <a href="https://colab.research.google.com/github/niranjay30/Sentdex_DS_Tuts/blob/master/pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/niranjay30/Sentdex_DS_Tuts/master/datasets/avocado.csv?token=AJIHUX3XNJKFRPMUSZRARSS6YQROG"
df = pd.read_csv(url)
df['Date'] = pd.to_datetime(df["Date"])
albany_df = df[df['region'] == 'Albany']
albany_df.set_index('Date', inplace=True)
albany_df["AveragePrice"].plot()

# %%
albany_df.sort_index(inplace=True)
albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()

# %%
albany_df.head(3)
# Out:
#             Unnamed: 0  ...  price25ma
# Date                    ...
# 2015-01-04          51  ...        NaN
# 2015-01-04          51  ...        NaN
# 2015-01-11          50  ...        NaN
#
# [3 rows x 15 columns]

# %%
albany_df.tail(3)
# Out:
#             Unnamed: 0  ...  price25ma
# Date                    ...
# 2018-03-18           1  ...     1.4276
# 2018-03-25           0  ...     1.4272
# 2018-03-25           0  ...     1.4368
#
# [3 rows x 15 columns]

# %%
albany_df.dropna().head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume  ...  year  region  price25ma
# Date                                                ...
# 2015-03-29          39          1.93       1082.44  ...  2015  Albany     1.4660
# 2015-03-29          39          1.02      67799.08  ...  2015  Albany     1.4580
# 2015-04-05          38          1.16      47362.13  ...  2015  Albany     1.4328
#
# [3 rows x 14 columns]

# %%
albany_df = df.copy()[df['region'] == 'Albany']
albany_df.set_index('Date', inplace=True)
albany_df.sort_index(inplace=True)
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()
